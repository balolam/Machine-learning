# %% [markdown]
# Работа с ранее загруженными постами с использованием <br>Scink-learn
# -------------------

# %%
# coding=utf-8
import numpy as np
import time

from elasticsearch import Elasticsearch
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# Функция, чтобы засекать время выполнеия метода

# %%
def timeit(method):
    def timed(*args, **kw):
        ts = time.time()
        result = method(*args, **kw)
        te = time.time()
            
        print 'func: %r -> %2.2f sec' % \
              (method.__name__, te-ts)
            
        return result

    return timed

# %%
@timeit
def get_indeces_by_prefix(database, prefix):
    def filter_by_prefix(indeces):
        return filter(lambda x: prefix in x, indeces)
    
    def get_all_indeces():
        return database.indices.get_aliases().keys()
    
    return filter_by_prefix(get_all_indeces())

# %%
@timeit
def clean_documents(docs):
    def notNull(doc):
        return doc is not None
    
    def notEmpty(doc):
        return not (not doc)
    
    def condition(doc):
        return notNull(doc) and notEmpty(doc)
    
    return [d for d in docs if condition(d)]

# %%
@timeit
def get_docmunets_by_index(database, index):
    result = database.search(index=str(index),
                             size=5000,
                             body={"query": {"match_all": {}}})
    
    records = result['hits'].get('hits')
    documents = [r.get('_source').get('message') for r in records] 
    
    return documents

# %%
@timeit
def get_documents_by_indices(database, indices):
    documents = []
    
    for index in indices:
        documents.extend(get_docmunets_by_index(database, index))
        
    return documents

# %%
database = Elasticsearch()

# %%
indices = get_indeces_by_prefix(database, "fb_group_posts_")
indices
# Out:
# func: 'get_indeces_by_prefix' -> 0.00 sec
# [u'fb_group_posts_newsone_122177661170978',
#  u'fb_group_posts_vice_news_235852889908002',
#  u'fb_group_posts_american_news_179035672287016',
#  u'fb_group_posts_yahoo_news_338028696036',
#  u'fb_group_posts_mtv_7245371700',
#  u'fb_group_posts_citynews_toronto_32204506174',
#  u'fb_group_posts_cnet_7155422274']

# %%
documents = get_documents_by_indices(database, indices)
documents = clean_documents(documents)
print "Получено документов:", len(documents)
# Out:
# func: 'get_docmunets_by_index' -> 0.07 sec
# func: 'get_docmunets_by_index' -> 0.05 sec
# func: 'get_docmunets_by_index' -> 0.05 sec
# func: 'get_docmunets_by_index' -> 0.07 sec
# func: 'get_docmunets_by_index' -> 0.04 sec
# func: 'get_docmunets_by_index' -> 0.06 sec
# func: 'get_docmunets_by_index' -> 0.05 sec
# func: 'get_documents_by_indices' -> 0.39 sec
# func: 'clean_documents' -> 0.02 sec
# Получено документов: 15810

# %%
vectorizer = CountVectorizer()
vectorizer
# Out:
# CountVectorizer(analyzer=u'word', binary=False, decode_error=u'strict',
#         dtype=<type 'numpy.int64'>, encoding=u'utf-8', input=u'content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern=u'(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %% [markdown]
# Подсчитаем кол-во вхожений некоторых токенов в нашем корпусе

# %%
def get_words_count(token, vocabulary, x):
    index = vocabulary.get(token)
    
    if index is None:
        return 0
    
    return sum(x[:, index])[0, 0]

# %%
words = [
    "is", "the", "data", "man", "women", "computer", "police", "bus", "love", "me"
]

matrix = vectorizer.fit_transform(documents)

for token in words:
    print "{:8}".format(token), "->", get_words_count(token, vectorizer.vocabulary_, matrix)
# Out:
# is       -> 5281
# the      -> 17127
# data     -> 41
# man      -> 520
# women    -> 251
# computer -> 36
# police   -> 853
# bus      -> 40
# love     -> 308
# me       -> 622
# i        -> 0

# %% [markdown]
# Всего уникальных токенов в копусе

# %%
len(vectorizer.vocabulary_)
# Out:
# 29600

# %% [markdown]
# # Использование Tfidf векторизатора

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer2 = TfidfVectorizer(ngram_range=(1, 2))
vectorizer2.fit_transform(documents)
vectorizer2
# Out:
# TfidfVectorizer(analyzer=u'word', binary=False, decode_error=u'strict',
#         dtype=<type 'numpy.int64'>, encoding=u'utf-8', input=u'content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 2), norm=u'l2', preprocessor=None, smooth_idf=True,
#         stop_words=None, strip_accents=None, sublinear_tf=False,
#         token_pattern=u'(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %% [markdown]
# Кол-во токенов корпуса

# %%
len(vectorizer2.vocabulary_)
# Out:
# 207401

# %%
words2 = [
    "are ok", "are", "ok", "classroom interface", "classroom", "interface"
]

matrix2 = vectorizer2.fit_transform(documents)

for token in words2:
    print "{:8}".format(token), "->", get_words_count(token, vectorizer2.vocabulary_, matrix2)
# Out:
# are ok   -> 0.243814053519
# are      -> 126.778929193
# ok       -> 2.01064107243
# classroom interface -> 0.188727170574
# classroom -> 0.929868587847
# interface -> 0.858251103706

# %%
vectorizer2.vocabulary_
# Out:
# {u'scandalous photos': 152123,
#  u'it absolutely': 93367,
#  u'announcing who': 16704,
#  u'russia syria': 150131,
#  u'regard http': 145309,
#  u'nine days': 120054,
#  u'approach the': 17984,
#  u'woods': 199775,
#  u'her our': 80984,
#  u'all working': 11086,
#  u'obscene acts': 122878,
#  u'comically': 42076,
#  u'mitzie hunter': 113316,
#  u'and artwork': 13806,
#  u'taliyah was': 167529,
#  u'sprague': 161672,
#  u'sexual assault': 154923,
#  u'changes in': 37684,
#  u'or just': 128938,
#  u'delegates platform': 50207,
#  u'protest roots': 140717,
#  u'fish bathe': 66233,
#  u'all class': 10781,
#  u'game customize': 71627,
#  u'of justin': 124239,
#  u'pythagorean theorem': 141825,
#  u'caught clinton': 36620,
#  u'magic show': 107385,
#  u'bakirk\xf6y cevizlik': 23378,
#  u'truly appreciate': 184199,
#  u'trojan': 183949,
#  u'education best': 57249,
#  u'news could': 119221,
#  u'touristes': 182753,
#  u'lies her': 102108,
#  u'jesus catches': 95082,
#  u'dissed the': 53434,
#  u'competition with': 42778,
#  u'bringing': 31545,
#  u'waters they': 193416,
#  u'woman journey': 199424,
#  u'decision mandating': 49665,
#  u'wooded': 199759,
#  u'the real': 173826,
#  u'horseradish and': 84173,
#  u'wooden': 199761,
#  u'content facebook': 44170,
#  u'karen': 96961,
#  u'wednesday': 194190,
#  u'could up': 45461,
#  u'movies have': 115462,
#  u'michoac\xe1n remains': 112009,
#  u'seeks to': 153505,
#  u'it serious': 93861,
#  u'your website': 203421,
#  u'old alexander': 126255,
#  u'filmmaker todd': 65318,
#  u'they told': 176664,
#  u'pickandpow': 135148,
#  u'own multi': 131382,
#  u'270': 3516,
#  u'paula jones': 133144,
#  u'272': 3535,
#  u'woman hostage': 199415,
#  u'you feeling': 202388,
#  u'probably didn': 139595,
#  u'80 mosques': 5827,
#  u'year frank': 201591,
#  u'mr president': 115544,
#  u'old homeless': 126377,
#  u'wildfire that': 197249,
#  u'now who': 122020,
#  u'www mynytaxi': 201106,
#  u'during school': 56415,
#  u'kung itutuloy': 99002,
#  u'console and': 43890,
#  u'now why': 122021,
#  u'time really': 179145,
#  u'public way': 141235,
#  u'the trudeau': 174567,
#  u'gets pulled': 72877,
#  u'performance as': 134118,
#  u'brewster she': 31360,
#  u'money by': 113821,
#  u'donate http': 54815,
#  u'died during': 52241,
#  u'didn apologize': 52149,
#  u'on 2017': 126726,
#  u'congo river': 43555,
#  u'be practically': 25084,
#  u'is unimaginable': 92787,
#  u'tree in': 183655,
#  u'your editors': 203035,
#  u'had total': 76809,
#  u'neutrality in': 118495,
#  u'british mp': 31631,
#  u'love decision': 104484,
#  u'murders don': 116030,
#  u'isaacs will': 92892,
#  u'hidden in': 81542,
#  u'affiliated': 8761,
#  u'smith year': 158853,
#  u'this little': 177497,
#  u'iranian government': 91444,
#  u'my devices': 116516,
#  u'kids': 97854,
#  u'uplifting': 187756,
#  u'historic day': 83036,
#  u'controversy': 44481,
#  u'sex misconceptions': 154861,
#  u'2ag4hsn': 4223,
#  u'kidd': 97817,
#  u'email us': 58129,
#  u'needs balls': 118126,
#  u'neal dow': 117796,
#  u'are joining': 18582,
#  u'december this': 49601,
#  u'tragedy of': 183125,
#  u'american freedom': 12687,
#  u'publicly admitted': 141260,
#  u'the specifics': 174219,
#  u'mclaurin': 110210,
#  u'evolution of': 61193,
#  u'film gay': 65276,
#  u'ly 295gvvu': 105998,
#  u'star omarosa': 162264,
#  u'during 2016': 56349,
#  u'is rio': 92543,
#  u'another distraction': 16801,
#  u'dna': 53748,
#  u'dnc': 53753,
#  u'to canada': 179785,
#  u'our cheapskate': 130073,
#  u'8m6c3003qb9': 5981,
#  u'they don': 176476,
#  u'refunding': 145258,
#  u'released months': 145755,
#  u'mystic': 116885,
#  u'movement conference': 115357,
#  u'kxze301x06u': 99057,
#  u'we ask': 193618,
#  u'aren really': 19099,
#  u'out scripts': 130611,
#  u'countries etc': 45627,
#  u'android powered': 16357,
#  u'text to': 169477,
#  u'costs uber': 45301,
#  u'profit returns': 140034,
#  u'populations': 137419,
#  u'yahoo': 201328,
#  u'group rule': 75823,
#  u'meteorologist': 111725,
#  u'history do': 83099,
#  u'can create': 34777,
#  u'born now': 30351,
#  u'kidding yourself': 97832,
#  u'slearz': 158462,
#  u'thursday to': 178794,
#  u'to prevent': 180931,
#  u'opened his': 128416,
#  u'about now': 6720,
#  u'citizen which': 39377,
#  u'weren eligible': 195063,
#  u'heaven but': 80151,
#  u'ly 1thnudp': 105350,
#  u'monkey out': 113975,
#  u'hyatt': 85639,
#  u'clinton donors': 40313,
#  u'address as': 8210,
#  u'address at': 8211,
#  u'way than': 193522,
#  u'illegal aliens': 86389,
#  u'tragic let': 183141,
#  u'way that': 193523,
#  u'29yvabl': 4111,
#  u'ly 1naqzdp': 104990,
#  u'the slop': 174171,
#  u'in panic': 88012,
#  u'news agency': 119164,
#  u'rights activists': 148436,
#  u'relying little': 145894,
#  u'man let': 108286,
#  u'gov john': 74761,
#  u'fear only': 64113,
#  u'com sephlawless': 41772,
#  u'obama off': 122633,
#  u'lost since': 104321,
#  u'week thoughts': 194326,
#  u'attacked mosque': 21642,
#  u'allegedly spent': 11230,
#  u'show how': 156707,
#  u'the dispute': 171888,
#  u'sexo playboy': 154907,
#  u'raydaghost': 143454,
#  u'rigged have': 148323,
#  u'her small': 81083,
#  u'beyond proportions': 27897,
#  u'arrested overnight': 19511,
#  u'conduct details': 43314,
#  u'haunting green': 78454,
#  u'wrong': 200869,
#  u'sentencing': 154130,
#  u'and plunder': 15382,
#  u'need them': 118064,
#  u'murders per': 116038,
#  u'same protected': 150979,
#  u'zeitonline_pol': 203718,
#  u'christ is': 38987,
#  u'probe of': 139636,
#  u'christ in': 38986,
#  u'produce more': 139823,
#  u'documentary about': 54090,
#  u'reveals everything': 147802,
#  u'another example': 16807,
#  u'headlines in': 79750,
#  u'new method': 118897,
#  u'welcomed': 194514,
#  u'meeting as': 110984,
#  u'message claimed': 111590,
#  u'un stated': 186135,
#  u'boltons': 29934,
#  u'tragedy do': 183122,
#  u'welcomes': 194527,
#  u'fir': 65782,
#  u'legendary journalist': 101282,
#  u'fit': 66274,
#  u'earns trip': 56819,
#  u'screaming': 152704,
#  u'fix': 66375,
#  u'striking': 164260,
#  u'ed curriculum': 57099,
#  u'www sunherald': 201140,
#  u'with kenny': 198580,
#  u'the bays': 171168,
#  u'1trjn8x': 2268,
#  u'fil': 65141,
#  u'speed dial': 161162,
#  u'\u0627\u0644\u062c\u0633\u062f': 204695,
#  u'chest saying': 38331,
#  u'decision lot': 49664,
#  u'freeze your': 69839,
#  u'including academics': 88727,
#  u'vouchers': 191153,
#  u'about jian': 6659,
#  u'woman president': 199434,
#  u'share https': 155221,
#  u'payne jr': 133300,
#  u'john honderich': 95414,
#  u'notion of': 121626,
#  u'50000 rs': 5214,
#  u'terroristes': 169217,
#  u'may set': 109937,
#  u'message dpaw_kent': 111594,
#  u'individuals claiming': 89222,
#  u'may increase': 109905,
#  u'animal articles': 16491,
#  u'observations especially': 122886,
#  u'monitoring committee': 113957,
#  u'the severed': 174083,
#  u'looks rosey': 104112,
#  u'of fun': 123984,
#  u'mattresses and': 109792,
#  u'expressing anti': 62116,
#  u'addressed http': 8244,
#  u'get closer': 72602,
#  u'for younger': 68484,
#  u'diving really': 53662,
#  u'hilariously worked': 81817,
#  u'of fur': 123988,
#  u'gotta leave': 74727,
#  u'famous friends': 63362,
#  u'of hyperventilation': 124130,
#  u'free without': 69752,
#  u'reading some': 143896,
#  u'reign into': 145511,
#  u'humber': 85394,
#  u'night dinners': 119909,
#  u'capital officer': 35534,
#  u'affected cities': 8734,
#  u'elections removed': 57808,
#  u'sang the': 151241,
#  u'their labour': 175202,
#  u'sorry via': 160445,
#  u'video exposed': 189931,
#  u'he accommodate': 79207,
#  u'witness to': 199251,
#  u'size': 158135,
#  u'just 12': 96219,
#  u'just 13': 96220,
#  u'just 10': 96218,
#  u'smiling in': 158815,
#  u'of cities': 123537,
#  u'abbott': 6302,
#  u'dgi': 51878,
#  u'california because': 34115,
#  u'welteroth': 194676,
#  u'captured in': 35610,
#  u'is crooked': 91848,
#  u'is reminder': 92522,
#  u'electronic mail': 57848,
#  u'bring everyone': 31510,
#  u'2016 defence': 2906,
#  u'lse department': 104715,
#  u'republicans immediately': 146833,
#  u'eve news': 60389,
#  u'taking seat': 167452,
#  u'about certain': 6537,
#  u'as presidential': 20175,
#  u'pfaff': 134635,
#  u'to find': 180233,
#  u'creatspace https': 46577,
#  u'constitution stating': 43985,
#  u'https wh': 85162,
#  u'knowing that': 98681,
#  u'saying illegals': 151857,
#  u'unveils new': 187365,
#  u'questions to': 142160,
#  u'and field': 14527,
#  u'obama slams': 122711,
#  u'weighs in': 194456,
#  u'tomorrow 72': 181979,
#  u'by hetero': 33430,
#  u'does actually': 54163,
#  u'ookla test': 128329,
#  u'spectre of': 161045,
#  u'film noir': 65286,
#  u'federal regulators': 64304,
#  u'to same': 181144,
#  u'he contemplated': 79288,
#  u'nuclear powered': 122094,
#  u'female politicans': 64605,
#  u'bird from': 28611,
#  u'needed': 118080,
#  u'our troops': 130408,
#  u'master': 109512,
#  u'day work': 48891,
#  u'egyptair plane': 57457,
#  u'political parties': 137048,
#  u'eyes what': 62365,
#  u'federal prison': 64299,
#  u'people unacceptable': 133939,
#  u'felt at': 64549,
#  u'business insider': 32665,
#  u'place how': 135579,
#  u'back stop': 22961,
#  u'and including': 14826,
#  u'berniesanders says': 27331,
#  u'spotted her': 161641,
#  u'in oakville': 87981,
#  u'put lotion': 141703,
#  u'returns are': 147707,
#  u'ahmed': 9909,
#  u'and burned': 13964,
#  u'vegans in': 189072,
#  u'as molly': 20095,
#  u'duckworth': 56197,
#  u'recaps the': 144422,
#  u'no headway': 120289,
#  u'\u0442\u0430\u0441\u0441 doni': 204441,
#  u'which suffer': 196068,
#  u'ahmet': 9918,
#  u'tutelage': 185208,
#  u'and using': 16110,
#  u'balloon drop': 23464,
#  u'ly 1qgo5n8': 105134,
#  u'respond back': 147317,
#  u'mobile with': 113438,
#  u'journalists are': 95767,
#  u'being deceptive': 26648,
#  u'wow can': 200690,
#  u'appeal bill': 17712,
#  u'please take': 136218,
#  u'old critically': 126306,
#  u'reaping the': 144263,
#  u'giving birth': 73478,
#  u'they dont': 176477,
#  u'amen if': 12417,
#  u'wikileaks dnc': 197204,
#  u'person passes': 134384,
#  u'circulating about': 39308,
#  u'have offended': 78772,
#  u'will benefit': 197310,
#  u'work related': 199951,
#  u'federal prosecutors': 64303,
#  u'profession they': 139951,
#  u'mcconnell compared': 110131,
#  u'kremlin': 98913,
#  u'ph\u0131l\u0131ps': 135094,
#  u'and hololens': 14756,
#  u'government would': 74934,
#  u'communities don': 42446,
#  u'resident said': 147098,
#  u'happen stem': 77355,
#  u'icloud': 85810,
#  u'on unarmed': 127465,
#  u'buzzy birth': 33216,
#  u'many rnc': 108764,
#  u'job doesn': 95251,
#  u'shading the': 155041,
#  u'ly 1qiqhed': 105138,
#  u'more style': 114550,
#  u'every one': 60874,
#  u'in history': 87699,
#  u'maja': 107571,
#  u'occupied the': 122995,
#  u'help pages': 80469,
#  u'tech': 168357,
#  u'fugitives': 70966,
#  u'tells katie': 168766,
#  u'rally tesla': 142963,
#  u'of interrogation': 124183,
#  u'good charlotte': 74248,
#  u'settles several': 154692,
#  u'bombers attacked': 29975,
#  u'yes2iraq': 201963,
#  u'mysterious notes': 116869,
#  u'nature unapologetic': 117647,
#  u'possible radical': 137700,
#  u'tempted': 168844,
#  u'writer has': 200800,
#  u'taken properly': 167325,
#  u'golchi the': 74092,
#  u'that rate': 170458,
#  u'first responders': 66152,
#  u'ali quotes': 10594,
#  u'to adapt': 179576,
#  u'vampire diaries': 188839,
#  u'of conspiring': 123615,
#  u'me\u015frutiyet el': 111838,
#  u'll bring': 103432,
#  u'stripped from': 164294,
#  u'much fainances': 115680,
#  u'decisions are': 49681,
#  u'upcoming artists': 187643,
#  u'hobby or': 83311,
#  u'the st': 174241,
#  u'just was': 96537,
#  u'heareth say': 79972,
#  u'spectacle during': 161029,
#  u'nelson taylor': 118321,
#  u'sure the': 166068,
#  u'nothing do': 121540,
#  u'themselves and': 175695,
#  u'important the': 86917,
#  u'the so': 174185,
#  u'and bjork': 13909,
#  u'provisional government': 141037,
#  u'election be': 57742,
#  u'of positive': 124685,
#  u'episode to': 59511,
#  u'away wit': 22590,
#  u'behaviorurldefaultvmlo': 26491,
#  u'patch': 132962,
#  u'suge knight': 165219,
#  u'emailid 8867': 58174,
#  u'higher fences': 81674,
#  u'from multitude': 70516,
#  u'manner in': 108577,
#  u'of solid': 124979,
#  u'derbent ikinci': 51095,
#  u'rule me': 149819,
#  u'emailid 578': 58161,
#  u'\u0647\u062f\u0641\u0627 \u0644\u062e\u0648\u0646\u0629': 205775,
#  u'keep controversial': 97250,
#  u'transplants and': 183421,
#  u'sociaty have': 159417,
#  u'children from': 38618,
#  u'takes nasty': 167371,
#  u'two games': 185541,
#  u'fair elections': 62905,
#  u'manner it': 108578,
#  u'model in': 113509,
#  u'says chief': 151922,
#  u'at banquet': 20982,
#  u'atat\xfcrk el': 21429,
#  u'weekend dedicated': 194366,
#  u'irs': 91540,
#  u'phone here': 134871,
#  u'weak this': 193913,
#  u'dismiss bill': 53218,
#  u'marijuana producer': 108960,
#  u'man buns': 108217,
#  u'irl': 91501,
#  u'theisraelproject': 175474,
#  u'ira': 91427,
#  u'ire': 91476,
#  u'wage': 191348,
#  u'credit and': 46608,
#  u'image on': 86518,
#  u'am making': 12160,
#  u'that to': 170627,
#  u'extend': 62139,
#  u'nature': 117640,
#  u'customer service': 47712,
#  u'fruits': 70873,
#  u'chess game': 38321,
#  u'poll also': 137181,
#  u'verbally physically': 189206,
#  u'husband was': 85605,
#  u'extent': 62167,
#  u'their hotel': 175175,
#  u'bilderberg http': 28350,
#  u'shelfish': 155797,
#  u'given us': 73436,
#  u'given up': 73435,
#  u'ly 1us1ko0': 105467,
#  u'fox viewers': 69396,
#  u'fatal shootings': 63711,
#  u'far but': 63510,
#  u'are on': 18681,
#  u'all journalists': 10897,
#  u'are ok': 18679,
#  u'you longing': 202502,
#  u'are of': 18673,
#  u'woman from': 199402,
#  u'buying food': 33170,
#  u'texts to': 169488,
#  u'treated like': 183611,
#  u'begin this': 26436,
#  u'whatever lister': 195515,
#  u'espn the': 59948,
#  u'barbecue in': 23881,
#  u'alice cooper': 10617,
#  u'of their': 125123,
#  u'1041475622607726': 701,
#  u'masters at': 109537,
#  u'flees the': 66609,
#  u'confinement robbery': 43416,
#  u'busiest in': 32634,
#  u'angel': 16389,
#  u'in account': 87157,
#  u'classroom interface': 39928,
#  u'protested news': 140735,
#  u'anchors it': 13621,
#  u'org dnc': 129337,
#  u'residing at': 147131,
#  u'california are': 34110,
#  u'attract the': 21893,
#  u'from morocco': 70508,
#  u'on men': 127160,
#  u'have redemption': 78828,
#  u'obese': 122831,
#  u'harmony in': 77722,
#  u'video will': 190136,
#  u'sanders claims': 151134,
#  u'harmony if': 77721,
#  u'woodbine about': 199755,
#  u'deserves for': 51227,
#  u'of lifetime': 124310,
#  u'month here': 114049,
#  u'doubts': 55132,
#  u'pathetic maybe': 132987,
#  u'guards on': 76028,
#  u'assistance have': 20779,
#  u'misconstrues': 112975,
#  u'13 on': 1062,
#  u'tony and': 182076,
#  u'that milf': 170319,
#  u'issue cnet': 93189,
#  u'pengujian obat': 133637,
#  u'13 of': 1061,
#  u'poppy fields': 137368,
#  u'misconstrued': 112973,
#  u'rescinds': 146953,
#  u'ncaa is': 117767,
#  u'geforce': 72154,
#  u're almost': 143514,
#  u'sunday june': 165540,
#  u'was saying': 192703,
#  u'galactic unveils': 71562,
#  u'to hundreds': 180417,
#  u'residence and': 147086,
#  u'she loved': 155609,
#  u'of transgender': 125179,
#  u'\u0648\u0645\u0627\u0643\u0627\u0646': 205937,
#  u'injustice by': 89736,
#  u'sanders as': 151127,
#  u'ontario is': 128274,
#  u'the onslaught': 173395,
#  u'memorial': 111209,
#  u'expensive for': 61772,
#  u'use nuclear': 188358,
#  u'cuba huge': 47369,
#  u'reuters mailonline': 147737,
#  u'tonight raptors': 182048,
#  u'the pretext': 173668,
#  u'korea has': 98856,
#  u'60 on': 5444,
#  u'an make': 13406,
#  u'luxury take': 104880,
#  u'ex wives': 61248,
#  u'cuidado del': 47420,
#  u'trumps record': 184682,
#  u'judge dismissed': 95901,
#  u'loudmouth obama': 104398,
#  u'live during': 103184,
#  u'pledge now': 136256,
#  u'khweis is': 97725,
#  u'weinstock': 194471,
#  u'no jail': 120303,
#  u'savescranton': 151631,
#  u'or restricting': 129063,
#  u'ly 1rt1z1u': 105224,
#  u'soviet controlled': 160651,
#  u'pm and': 136389,
#  u'shot but': 156404,
#  u'are petitioning': 18718,
#  u'rewarded mightily': 147982,
#  u'still ain': 163254,
#  u'ever focussed': 60725,
#  u'only carries': 128070,
#  u'me see': 110435,
#  u'between children': 27689,
#  u'accurately portray': 7421,
#  u'sure but': 166048,
#  u'graham publicly': 75113,
#  u'29uxzuz': 4061,
#  u'being tempted': 26813,
#  u'\u0648\u0648\u0627\u0644\u062f\u0646\u0627\u062c\u0644\u0627\u0644\u0629': 205949,
#  u'week deadly': 194256,
#  u'discrimination within': 52974,
#  u'for devil': 67598,
#  u'bellow': 27041,
#  u'pale skin': 131894,
#  u'exceeds what': 61351,
#  u'waterboard': 193387,
#  u'unirush': 186812,
#  u'but scare': 32974,
#  u'prospective customers': 140580,
#  u'advancement': 8563,
#  u'for poisoning': 68074,
#  u'establishment stop': 60018,
#  u'during howard': 56378,
#  u'1996 have': 1774,
#  u'gofundme 200': 74025,
#  u'youtube of': 203557,
#  u'back please': 22943,
#  u'the gravitational': 172426,
#  u'moving until': 115491,
#  u'sexywoman sexymodel': 154986,
#  u'clinching their': 40217,
#  u'whether this': 195931,
#  u'bh15300kqwk': 27956,
#  u'historic sit': 83053,
#  u'indicative': 89139,
#  u'and cats': 14015,
#  u'decision taken': 49671,
#  u'since woodrow': 157683,
#  u'delivery of': 50356,
#  u'the museum': 173239,
#  u'ferguson west': 64719,
#  u'thanks everyone': 169775,
#  u'will still': 197577,
#  u'exiting the': 61646,
#  u'misdemeanors': 112979,
#  u'a\xf1os de': 22740,
#  u'crowd': 47074,
#  u'crowe': 47136,
#  u'birth system': 28651,
#  u'i01c300hhpg': 85743,
#  u'crown': 47141,
#  u'merchants about': 111482,
#  u'make money': 107760,
#  u'executed by': 61502,
#  u'werner herzog': 195078,
#  u'n650 000': 116962,
#  u'win all': 197743,
#  u'have advised': 78475,
#  u'embodiment of': 58288,
#  u'pfizer admits': 134641,
#  u'lockdown': 103677,
#  u'94 brown': 6096,
#  u'29wmjws': 4078,
#  u'jymw300lt9g': 96684,
#  u'bai and': 23293,
#  u'seen outside': 153582,
#  u'hellerstedt': 80329,
#  u'fired from': 65875,
#  u'better suited': 27637,
#  u'organization ariane': 129379,
#  u'her 97': 80655,
#  u'sad he': 150358,
#  u'high 18': 81596,
#  u'company who': 42694,
#  u'southern indian': 160627,
#  u'sunday night': 165545,
#  u'nj\xeb karrig\xeb': 120143,
#  u'and sexuality': 15710,
#  u'pikachu as': 135294,
#  u'get people': 72717,
#  u'sparks safety': 160803,
#  u'ptsd': 141129,
#  u'reporter amanda': 146576,
#  u'sorry not': 160436,
#  u'speeding stops': 161177,
#  u'no response': 120404,
#  u'rally for': 142953,
#  u'existing iphone': 61628,
#  u'kardashian west': 96956,
#  u'them into': 175568,
#  u'station just': 162825,
#  u'high turnout': 81662,
#  u'home actually': 83557,
#  u'election during': 57754,
#  u'america diversity': 12487,
#  u'marshall': 109207,
#  u'honeymoon': 83843,
#  u'can duplicate': 34798,
#  u'we take': 193857,
#  u'80 percent': 5832,
#  u'finally here': 65449,
#  u'husband ever': 85581,
#  u'got political': 74677,
#  u'ly 1nq8s7p': 105012,
#  u'by 13': 33221,
#  u'fabric': 62471,
#  u'aluminium and': 11964,
#  u'minnesota speaking': 112811,
#  u'yet live': 202017,
#  u'2014 you': 2816,
#  u'and face': 14481,
#  u'raped': 143182,
#  u'petition to': 134591,
#  u'nra finds': 122053,
#  u'seriously with': 154350,
#  u'rapes': 143192,
#  u'lil john': 102739,
#  u'ringer for': 148552,
#  u'canada played': 35107,
#  u'and fact': 14486,
#  u'com app': 41549,
#  u'ces actes': 37316,
#  u'\u0908\u0915 \u0906\u0938': 206149,
#  u'developing african': 51724,
#  u'\u0c85\u0ca8 \u0cb8\u0cb2': 206838,
#  u'not dead': 121018,
#  u'purple drank': 141576,
#  u'pedestrians on': 133521,
#  u'decades according': 49546,
#  u'puts her': 141768,
#  u'bao thu\u1ebf': 23819,
#  u'congratulations': 43580,
#  u'humbled': 85400,
#  u'layia': 100431,
#  u'benefiting certain': 27184,
#  u'yeni\u015fehir el': 201839,
#  u'trump http': 184408,
#  u'hashtag illbeback': 78263,
#  u'even younger': 60565,
#  u'fallon host': 63055,
#  u'from friend': 70363,
#  u'involving americans': 91300,
#  u'trapped ivy': 183456,
#  u'students if': 164546,
#  u'most extreme': 114880,
#  u'in armenia': 87207,
#  u'1qu3frr': 2007,
#  u'mercedesbenz ml350': 111466,
#  u'students in': 164547,
#  u'trump inviting': 184421,
#  u'passenger': 132762,
#  u'in student': 88287,
#  u'old christy': 126298,
#  u'of male': 124362,
#  u'canceled their': 35235,
#  u'around her': 19386,
#  u'in collaboration': 87372,
#  u'racism he': 142568,
#  u'kids facts': 97870,
#  u'american so': 12756,
#  u'she awoke': 155462,
#  u'violence will': 190495,
#  u'\u5176\u62ba\u9ed1\u6211\u7684\u53f8\u99ac\u662d\u4e4b\u5fc3 \u771f\u662f\u8def\u4eba\u7686\u898b': 207001,
#  u'needing these': 118113,
#  u'come visit': 41954,
#  u'poor captain': 137299,
#  u'cambodia': 34423,
#  u'baraka with': 23861,
#  u'where going': 195825,
#  u'got reported': 74684,
#  u'sophomore nayla': 160393,
#  u'various events': 188939,
#  u'alert prediction': 10502,
#  u'concerns inevitably': 43160,
#  u'principal pleads': 139346,
#  u'thriller films': 178414,
#  u'palms': 131931,
#  u'sale to': 150772,
#  u'widow steatoda': 197122,
#  u'like trams': 102634,
#  u'like poverty': 102572,
#  u'yellowstone': 201801,
#  u'le est': 100471,
#  u'tens of': 168913,
#  u'venezuelan brothers': 189168,
#  u'usa wash': 188257,
#  u'international human': 90515,
#  u'salacak el': 150731,
#  u'his month': 82726,
#  u'accepted into': 7181,
#  u'http sephlawless': 85086,
#  u'sticky situation': 163241,
#  u'v1af301gczh': 188679,
#  u'few taps': 64873,
#  u'you cole': 202311,
#  u'being queer': 26766,
#  u'leader senator': 100557,
#  u'cnet bonnie': 40754,
#  u'laden backpack': 99295,
#  u'global attention': 73598,
#  u'works on': 200099,
#  u'chain': 37371,
#  u'whoever': 196799,
#  u'asleep dr': 20571,
#  u'works of': 200098,
#  u'daily evening': 48019,
#  u'un documental': 186114,
#  u'that begins': 169891,
#  u'kae month': 96777,
#  u'chair': 37390,
#  u'18 may': 1481,
#  u'among white': 12955,
#  u'in 1914': 87073,
#  u'ballet': 23455,
#  u'nations said': 117573,
#  u'grapples': 75240,
#  u'committing suicide': 42352,
#  u'in 1912': 87072,
#  u'fight away': 65017,
#  u'wants americans': 191778,
#  u'list was': 102981,
#  u'mateen current': 109602,
#  u'the different': 171857,
#  u'link http': 102882,
#  u'innocent man': 89798,
#  u'china might': 38728,
#  u'perfect score': 134082,
#  u'zoo enclosure': 203871,
#  u'de porno': 49071,
#  u'flatbed': 66555,
#  u'government got': 74851,
#  u'now professor': 121926,
#  u'ttc guard': 184850,
#  u'exact': 61251,
#  u'minute': 112862,
#  u'ryan delivers': 150213,
#  u'soldiers deserve': 159589,
#  u'amazed video': 12249,
#  u'mindset justice': 112659,
#  u'just watch': 96539,
#  u'right video': 148410,
#  u'athletes is': 21491,
#  u'talks of': 167597,
#  u'pd addresses': 133410,
#  u'in decade': 87453,
#  u'hashtag bringbackourgirls': 78261,
#  u'like tarzan': 102614,
#  u'bajet': 23346,
#  u'ly 1syodn6': 105296,
#  u'the guardians': 172454,
#  u'article makes': 19648,
#  u'lower your': 104675,
#  u'after locating': 9109,
#  u'your electronics': 203039,
#  u'torpid intimidated': 182557,
#  u'shirt consoled': 155976,
#  u'the research': 173886,
#  u'newark new': 119103,
#  u'45am et': 4949,
#  u'you shouldn': 202664,
#  u'fees to': 64480,
#  u'which destroyed': 195974,
#  u'in diet': 87482,
#  u'america respond': 12580,
#  u'definitely bit': 50026,
#  u'\u7adf\u7136\u5229\u7528\u5c0f\u5b69\u5b50\u505a\u51fa\u6050\u5687\u6211\u5bb6\u7684\u72af\u6cd5\u884c\u70ba': 207242,
#  u'huge mistake': 85255,
#  u'team lannister': 168270,
#  u'antwerp': 17109,
#  u'abdullah': 6362,
#  u'\u064a\u062a\u0648\u0633\u0644': 205974,
#  u'doing job': 54445,
#  u'suggest that': 165222,
#  u'absorb every': 6983,
#  u'spies were': 161319,
#  u'out loud': 130572,
#  u'hip working': 82304,
#  u'and sexualized': 15711,
#  u'most highly': 114896,
#  u'to forgive': 180265,
#  u'md explain': 110266,
#  u'liked them': 102670,
#  u'software they': 159493,
#  u'sponsor review': 161491,
#  u'ly 1swjyvp': 105288,
#  u'claim also': 39665,
#  u'nichols videos': 119799,
#  u'oldies': 126593,
#  u'family shocked': 63305,
#  u'is playing': 92424,
#  u'binigyan': 28556,
#  u'but spotify': 32989,
#  u'for divorce': 67608,
#  u'had drowned': 76683,
#  u'\u0627\u0644\u0646\u064a\u0631\u0629 \u0648\u0627\u0644\u062a\u064a': 204903,
#  u'bbm 5a8c4af6': 24486,
#  u'their electronic': 175088,
#  u'understanding what': 186509,
#  u'that affect': 169826,
#  u'stating he': 162809,
#  u'fiyatlari e\u015fya': 66425,
#  u'maria monteleone': 108931,
#  u'still rejected': 163356,
#  u'documents for': 54120,
#  u'clothing line': 40660,
#  u'anyone going': 17352,
#  u'to dream': 180082,
#  u'selfie mic': 153746,
#  u'are when': 19013,
#  u'abouzaher': 6876,
#  u'\u0641\u064a\u0647\u0645': 205465,
#  u'of ticket': 125152,
#  u'obama my': 122619,
#  u'of ticker': 125151,
#  u'called wind': 34333,
#  u'has paid': 78085,
#  u'00 but': 8,
#  u'word is': 199812,
#  u'little friends': 103097,
#  u'word in': 199811,
#  u'river since': 148765,
#  u'some familiar': 159798,
#  u'file mtv': 65161,
#  u'word if': 199810,
#  u'formy teenchoice': 69014,
#  u'victim makes': 189768,
#  u'lisa identity': 102950,
#  u'delivering regular': 50335,
#  u'\u98df\u5ba2 \u5916\u8ce3\u54e1': 207382,
#  u'say something': 151792,
#  u'narcos season': 117267,
#  u'cannot believe': 35442,
#  u'bumpersticker so': 32406,
#  u'sound bars': 160496,
#  u'release docs': 145707,
#  u'move health': 115304,
#  u'unite with': 186840,
#  u'disabilities advocate': 52716,
#  u'design work': 51256,
#  u'\u09e9\u09e6 \u09e9\u09e6': 206829,
#  u'street restaurant': 164150,
#  u'approving': 18043,
#  u'no enemy': 120250,
#  u'1sqsqyc': 2129,
#  u'well to': 194640,
#  u'kidnapped chibok': 97836,
#  u'cpalead com': 46223,
#  u'tomorrow is': 181994,
#  u'short for': 156357,
#  u'not gain': 121100,
#  u'20th century': 3081,
#  u'rutherford': 150182,
#  u'rare occasions': 143291,
#  u'unidos sa': 186714,
#  u'program chip': 140069,
#  u'following': 67107,
#  u'neighbors tell': 118266,
#  u'600mah': 5460,
#  u'cleo as': 40077,
#  u'had against': 76638,
#  u'accept it': 7142,
#  u'zannett': 203675,
#  u'say she': 151787,
#  u'cruz quit': 47263,
#  u'donald to': 54789,
#  u'kirk franklin': 98365,
#  u'mentality': 111392,
#  u'of baltimore': 123340,
#  u'sandarbhama 4o': 151114,
#  u'data get': 48519,
#  u'allies are': 11316,
#  u'conditions an': 43278,
#  u'clinton donations': 40312,
#  u'and equipment': 14424,
#  u'the mississauga': 173159,
#  u'litre': 103060,
#  u'australia please': 22095,
#  u'adults had': 8535,
#  u'that asking': 169864,
#  u'of promises': 124737,
#  u'simply vouch': 157541,
#  u'filed the': 65192,
#  u'thanking': 169765,
#  u'000 for': 83,
#  u'11 memorial': 824,
#  u'you let': 202490,
#  u'rover morning': 149648,
#  u'corporations discussing': 45088,
#  u'reilly if': 145526,
#  u'queen goes': 142016,
#  ...}
